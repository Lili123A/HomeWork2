# %% [markdown]
# <a href="https://colab.research.google.com/github/Lili123A/HomeWork2/blob/main/_%D1%81%D0%B0%D0%BC%D0%BE%D1%81%D1%82%D0%BE%D1%8F%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1

# %%
a=int(input())
b=int(input())
c=int(input())
while a!=b:
  if a>b:
    a=a-b
  else:
    b=b-a

while a!=c:
  if a>c:
    a=a-c
  else:
    c=c-a
print(a)
# Out:
# 30
# 60
# 45
# 15

# %% [markdown]
# 2

# %%
import math
n = int(input("n="))
x = float(input("x="))
S = 0
original_x = x
for _ in range(n):
    x = math.tan(x)
    S += x
print(S)
# Out:
# n=6
# x=5
# Сумма S: -4.651017906894419

# %% [markdown]
# 3

# %%
import math
x = 0.001
S = 0
n = 1
while True:
    a_n = math.factorial(n) / math.factorial(3 * n + 1)
    if a_n < x:
        break
    S += a_n
    n += 1
print( S)
# Out:
# 0.041666666666666664

# %%
n=int(input('n='))
m=int(input('m='))
if 4<=m<=9:
  print(3)
elif 10<=m<=15:
  print(5)
# Out:
# n=1
# m=11
# 5

# %%
n=int(input('n='))
m=int(input('m='))
t=m//3
if m>n*3:
  print("квартиры нет на этаже")

elif t==1 or t==2:
  print(3)
elif t==3 or t==4:
  print(5)
elif t==5 or t==6:
  print(7)
# Out:
# n=6
# m=65
# квартиры нет на этаже

# %% [markdown]
# 4

# %%
m=int(input('m='))
n=int(input('n='))
if m//n==m/n:
  print (m//n)
else:
  print("m на n на цело не делится")
# Out:
# m=24
# n=5
# m на n на цело не делится

# %% [markdown]
# 5

# %%
a=int(input('a='))
b=int(input('b='))
c=int(input('c='))
d=int(input('d='))
z=1<=abs(a-b)<=2 and 1<=abs(c-d)<=2
if not z:

  print ("угрожает")
else:
  print("не угрожает")
# Out:
# a=4
# b=4
# c=5
# d=6
# угрожает
