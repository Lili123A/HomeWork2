# %% [markdown]
# <a href="https://colab.research.google.com/github/Lili123A/HomeWork2/blob/main/%D0%A0%D0%B0%D0%B1%D0%BE%D1%82%D0%B0%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1

# %%
x=int(input('x='))
if x<=13:
  f=-x**3+9
else:
  f=-3/(x+1)
print(f)
# Out:
# x=99
# -0.03

# %% [markdown]
# 2

# %%
m=int(input('m='))
n=int(input('n='))
p=int(input('p='))
k=0
if m<0:
  k=k+1
if n<0:
  k=k+1
if p<0:
  k=k+1
print(k)
# Out:
# m=+4
# n=6
# p=-3
# 1

# %% [markdown]
# 3

# %%
n=int(input('n='))
m=int(input('m='))
if m in [4,5,6,7,8,9]:
  print(3)
elif m in [10,11,12,13,14,15]:
  print(5)
# Out:
# n=14
# m=14
# 5

# %%
n=int(input('n='))
m=int(input('m='))
if 4<=m<=9:
  print(3)
elif 10<=m<=15:
  print(5)
# Out:
# n=1
# m=11
# 5

# %%
n=int(input('n='))
m=int(input('m='))
t=m//3
if m>n*3:
  print("такой квартиры нет")

elif t==1 or t==2:
  print(3)
elif t==3 or t==4:
  print(5)
elif t==5 or t==6:
  print(7)
# Out:
# n=2
# m=9
# такой квартиры нет

# %% [markdown]
# 4

# %%
m=int(input('m='))
n=int(input('n='))
if m//n==m/n:
  print (m//n)
else:
  print("m на n на цело не делится")
# Out:
# m=24
# n=5
# m на n на цело не делится

# %% [markdown]
# 5

# %%
a=int(input('a='))
b=int(input('b='))
c=int(input('c='))
d=int(input('d='))
z=1<=abs(a-b)<=2 and 1<=abs(c-d)<=2
if not z:

  print ("угрожает")
else:
  print("не угрожает")
# Out:
# a=4
# b=4
# c=5
# d=6
# угрожает
