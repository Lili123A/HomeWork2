# %% [markdown]
# <a href="https://colab.research.google.com/github/Lili123A/HomeWork2/blob/main/HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 1

# %%
x=float(input('x='))
y=(x*x-4*x+4)/((x+5)**2-49)
print(y)
# Out:
# x=1
# -0.07692307692307693

# %% [markdown]
# 2

# %%
from math import sin,cos,tan
x=float(input('x='))
y=float(input('У='))
z=((sin(x)+cos(y))/(cos(x)-sin(y)))*tan(x*y)
print(z)
# Out:
# x=1
# У=1
# -7.145445549638803

# %% [markdown]
# 3

# %%
a=float(input('a='))
b=float(input('b='))
P=(a**2+b**2)**0.5+a+b
S=(a*b)/2
print(P,S)
# Out:
# a=2
# b=2
# 6.82842712474619 2.0

# %% [markdown]
# 4

# %%
a=int(input('a='))
b=a%1000
c=b//100
print(c)
# Out:
# a=14785
# 7

# %% [markdown]
# 5

# %%
A=float(input('A='))
B=float(input('A='))
A<=0
B<-2
print(z)
